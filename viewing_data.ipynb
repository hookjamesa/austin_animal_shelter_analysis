# %%
# Importing dependencies.
import pandas as pd

# %%
# Read in files.
file_path = "Resources/aac_intakes_outcomes.csv"
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#   age_upon_outcome animal_id_outcome        date_of_birth outcome_subtype  \
# 0         10 years           A006100  2007-07-09 00:00:00             NaN
# 1          7 years           A006100  2007-07-09 00:00:00             NaN
# 2          6 years           A006100  2007-07-09 00:00:00             NaN
# 3         10 years           A047759  2004-04-02 00:00:00         Partner
# 4         16 years           A134067  1997-10-16 00:00:00             NaN
#
#       outcome_type sex_upon_outcome  age_upon_outcome_(days)  \
# 0  Return to Owner    Neutered Male                     3650
# 1  Return to Owner    Neutered Male                     2555
# 2  Return to Owner    Neutered Male                     2190
# 3         Transfer    Neutered Male                     3650
# 4  Return to Owner    Neutered Male                     5840
#
#    age_upon_outcome_(years) age_upon_outcome_age_group     outcome_datetime  \
# ...

# %%
# Viewing our data types
df.dtypes
# Out:
# age_upon_outcome               object
# animal_id_outcome              object
# date_of_birth                  object
# outcome_subtype                object
# outcome_type                   object
# sex_upon_outcome               object
# age_upon_outcome_(days)         int64
# age_upon_outcome_(years)      float64
# age_upon_outcome_age_group     object
# outcome_datetime               object
# outcome_month                   int64
# outcome_year                    int64
# outcome_monthyear              object
# outcome_weekday                object
# outcome_hour                    int64
# outcome_number                float64
# dob_year                        int64
# dob_month                       int64
# dob_monthyear                  object
# age_upon_intake                object
# animal_id_intake               object
# animal_type                    object
# breed                          object
# color                          object
# found_location                 object
# ...

# %%
# Checking for nan
df.count()
# Out:
# age_upon_outcome              79672
# animal_id_outcome             79672
# date_of_birth                 79672
# outcome_subtype               36348
# outcome_type                  79662
# sex_upon_outcome              79671
# age_upon_outcome_(days)       79672
# age_upon_outcome_(years)      79672
# age_upon_outcome_age_group    79672
# outcome_datetime              79672
# outcome_month                 79672
# outcome_year                  79672
# outcome_monthyear             79672
# outcome_weekday               79672
# outcome_hour                  79672
# outcome_number                79672
# dob_year                      79672
# dob_month                     79672
# dob_monthyear                 79672
# age_upon_intake               79672
# animal_id_intake              79672
# animal_type                   79672
# breed                         79672
# color                         79672
# found_location                79672
# intake_condition              79672
# ...

# %%
# Dropping nan
df.dropna(inplace=True)

# %%
# Analyzing remaining data
df.count()
# Out:
# age_upon_outcome              36348
# animal_id_outcome             36348
# date_of_birth                 36348
# outcome_subtype               36348
# outcome_type                  36348
# sex_upon_outcome              36348
# age_upon_outcome_(days)       36348
# age_upon_outcome_(years)      36348
# age_upon_outcome_age_group    36348
# outcome_datetime              36348
# outcome_month                 36348
# outcome_year                  36348
# outcome_monthyear             36348
# outcome_weekday               36348
# outcome_hour                  36348
# outcome_number                36348
# dob_year                      36348
# dob_month                     36348
# dob_monthyear                 36348
# age_upon_intake               36348
# animal_id_intake              36348
# animal_type                   36348
# breed                         36348
# color                         36348
# found_location                36348
# intake_condition              36348
# ...

# %%
# Selecting columns.
df_samp = df.filter(["animal_id_outcome", "outcome_subtype", "outcome_type", "sex_upon_outcomes", 
            "age_upon_outcome_(years)", "age_upon_outcome_age_group", "outcome_monthyear", "age_upon_intake", 
            "animal_id_intake", "animal_type", "breed", "color", "intake_condition", "age_upon_intake_(years)", 
            "intake_year", "time_in_shelter_days"], axis=1)

# %%
# Sample for dataframe.
aac_sample = df_samp.sample(n=100)

# %%
# Ensuring sample was taken
aac_sample.count()
# Out:
# animal_id_outcome             100
# outcome_subtype               100
# outcome_type                  100
# age_upon_outcome_(years)      100
# age_upon_outcome_age_group    100
# outcome_monthyear             100
# age_upon_intake               100
# animal_id_intake              100
# animal_type                   100
# breed                         100
# color                         100
# intake_condition              100
# age_upon_intake_(years)       100
# intake_year                   100
# time_in_shelter_days          100
# dtype: int64

# %%
# New dataframe types.
aac_sample.dtypes
# Out:
# animal_id_outcome              object
# outcome_subtype                object
# outcome_type                   object
# age_upon_outcome_(years)      float64
# age_upon_outcome_age_group     object
# outcome_monthyear              object
# age_upon_intake                object
# animal_id_intake               object
# animal_type                    object
# breed                          object
# color                          object
# intake_condition               object
# age_upon_intake_(years)       float64
# intake_year                     int64
# time_in_shelter_days          float64
# dtype: object

# %%
## View dataframe
aac_sample.head()
# Out:
#       animal_id_outcome outcome_subtype outcome_type  \
# 2869            A637834         Partner     Transfer
# 30175           A699807            SCRP     Transfer
# 46174           A720887         Partner     Transfer
# 2285            A619134      Aggressive   Euthanasia
# 13488           A677706         Partner     Transfer
#
#        age_upon_outcome_(years) age_upon_outcome_age_group outcome_monthyear  \
# 2869                   6.000000                 (5.0, 7.5]           2015-09
# 30175                  2.000000              (-0.025, 2.5]           2015-04
# 46174                  2.000000              (-0.025, 2.5]           2016-02
# 2285                   6.000000                 (5.0, 7.5]           2016-03
# 13488                  0.076712              (-0.025, 2.5]           2014-04
#
#       age_upon_intake animal_id_intake animal_type  \
# 2869          6 years          A637834         Dog
# 30175         2 years          A699807         Cat
# ...

# %%
# Extracing file.
aac_sample.to_csv('../data/aac_sample.csv', index=True)
